# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathibha-bm/take_it_smart/blob/main/class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LIST

# %%
list=[1,2,3,5,6,7,8]
print(list)
if 10 in list:
  print("yes")
else:
  print("no")
# Out:
# [1, 2, 3, 5, 6, 7, 8]
# no

# %%
new_item=int(input("Enter New Item: "))
list.append(new_item)
print("updated list ",list)

remove_item=int(input("Enter New Item: "))
list.remove(remove_item)
print("updated list ",list)
# Out:
# Enter New Item: 10
# updated list  [1, 2, 3, 5, 6, 7, 8, 20, 10]
# Enter New Item: 20
# updated list  [1, 2, 3, 5, 6, 7, 8, 10]

# %%
size_list=int(input("Enter Size of List: "))
for i in range(size_list):
  new_item=int( input("enter new item :"))
  list.append(new_item)
print("Updated List:",list)
# Out:
# Enter Size of List: 3
# enter new item :3
# enter new item :3
# enter new item :2
# Updated List: [1, 2, 3, 5, 6, 7, 8, 10, 3, 3, 2]

# %% [markdown]
# 1.
# Build a chat bot using elif
# add,remove,replace,exit,viwe listif the choo add item whatever items they wanna remove they can replace while True

# %%
items = []
print(" add, remove, replace, view, exit")
while True:
    choice = input("\nWhat do you want to do? ").lower()
    if choice == "add":
        item = input("Enter item to add: ")
        items.append(item)
        print(f" '{item}' added successfully.")
    elif choice == "remove":
        item = input("Enter item to remove: ")
        if item in items:
            items.remove(item)
            print(f" '{item}' removed successfully.")
        else:
            print(" Item not found in the list.")
    elif choice == "replace":
        old_item = input("Enter item to replace: ")
        if old_item in items:
            new_item = input("Enter new item: ")
            index = items.index(old_item)
            items[index] = new_item
            print(f" '{old_item}' replaced with '{new_item}'.")
        else:
            print(" Item not found in the list.")
    elif choice == "view":
        if items:
            print(" Your items:")
            for i, item in enumerate(items, start=1):
                print(f"{i}. {item}")
        else:
            print(" The list is empty.")
    elif choice == "exit":
        print(" Goodbye Thanks for using List Bot.")
        break
    else:
        print(" Invalid choice. Please try again.")
# Out:
#  add, remove, replace, view, exit
#  '1,2,3' added successfully.
#  Item not found in the list.
#  '1,2,3' removed successfully.
#  '1' added successfully.
#  '2' added successfully.
#  Your items:
# 1. 1
# 2. 2
#  '1,2,3' added successfully.
#  Your items:
# 1. 1
# 2. 2
# 3. 1,2,3

# %%
items = []
print(" add, remove, replace, view, exit")

while True:
    choice = input("\nWhat do you want to do? ").lower()

    if choice == "add":
      len_list=int(input("Enter Size of List: "))
      for i in range(len_list):
        new_item=int( input("enter new item :"))
        list.append(new_item)
      print("Updated List:",list)
    elif choice=='remove':
       remove_item=int(input("enter item to remove:"))
       list.remove(remove_item)
       print("updated list",list)
      elif choice=='replace':
        old_item=int(input("Enter old item:"))
        if old+item in list:
          new_item=int(input("Enter new item:"))
          index=list.index(old_item)
          list[index_old]=new_item
          print("updated list",list)
        elif choice

# %% [markdown]
# CODINGBAT problems

# %% [markdown]
# 1. Given an array of ints, return True if 6 appears as either the first or last element in the array. The array will be length 1 or more.
#
# first_last6([1, 2, 6]) → True
#
# first_last6([6, 1, 2, 3]) → True
#
# first_last6([13, 6, 1, 2, 3]) → False

# %%
def first_last6(nums):
  if nums[0]==6 or nums[-1]==6:
   return True
  else:
    return False

# %% [markdown]
# 2. Given an array of ints, return True if the array is length 1 or more, and the first element and the last element are equal.
#
#
# same_first_last([1, 2, 3]) → False
#
# same_first_last([1, 2, 3, 1]) → True
#
# same_first_last([1, 2, 1]) → True

# %%
def same_first_last(nums):
  if len(nums)>=1 and (nums[0]==nums[-1]):
    return True
  else:
    return False

# %% [markdown]
# 3. Return an int array length 3 containing the first 3 digits of pi, {3, 1, 4}.
# make_pi() → [3, 1, 4]

# %%
def make_pi():
  arr=[3,1,4]
  return arr

# %% [markdown]
# 4. Given 2 arrays of ints, a and b, return True if they have the same first element or they have the same last element. Both arrays will be length 1 or more.
#
# common_end([1, 2, 3], [7, 3]) → True
#
# common_end([1, 2, 3], [7, 3, 2]) → False
#
# common_end([1, 2, 3], [1, 3]) → True

# %%
def common_end(a, b):
  if a[0]==b[0] or a[-1]==b[-1]:
   return True
  else :
    return False

# %% [markdown]
# 5. Given an array of ints length 3, return the sum of all the elements.
#
#
# sum3([1, 2, 3]) → 6
# sum3([5, 11, 2]) → 18
# sum3([7, 0, 0]) → 7

# %%
def sum3(nums):
  return sum(nums)

# %% [markdown]
# 6. Given an array of ints length 3, return an array with the elements "rotated left" so {1, 2, 3} yields {2, 3, 1}.
#
#
# rotate_left3([1, 2, 3]) → [2, 3, 1]
# rotate_left3([5, 11, 9]) → [11, 9, 5]
# rotate_left3([7, 0, 0]) → [0, 0, 7]

# %%
def rotate_left3(nums):
  return [nums[1], nums[2], nums[0]]
